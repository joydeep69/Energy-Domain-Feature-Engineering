# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
col=["age","workclass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","c_gain","c-loss","hrs_wk","country","income"]

# %%
df1=pd.read_csv("Assign1.train.csv",header=None,names=col)
df2=pd.read_csv("Assign1.test.csv",header=None,names=col)

# %%
df1.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    c_gain  c-loss  hrs_wk         country  income
# 0    2174       0      40   United-States   <=50K
# ...

# %%
# Merge the dataset -Train & Test

df3=df1.append(df2)

# %%
df1.shape
# Out:
# (32561, 15)

# %%
df2.shape
# Out:
# (16281, 15)

# %%
df3.shape
# Out:
# (48842, 15)

# %%
df3.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# c_gain             int64
# c-loss             int64
# hrs_wk             int64
# country           object
# income            object
# dtype: object

# %%
# Observations: 15 Variables(14+1) with 48842 Observations
# 5 IVs-Numeric-Continous
#9 IVs-Categorical-Object
# 1 Dv -Categorical -Object

# %%
# Cleaning the Data-set wrt Junk Values,Null Values..

# %%
df3.isnull().sum() # No null values for the whole date se
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# c_gain            0
# c-loss            0
# hrs_wk            0
# country           0
# income            0
# dtype: int64

# %%
set(df3.workclass)# Missing value object identified as junk object("?")
# Out:
# {' ?',
#  ' Federal-gov',
#  ' Local-gov',
#  ' Never-worked',
#  ' Private',
#  ' Self-emp-inc',
#  ' Self-emp-not-inc',
#  ' State-gov',
#  ' Without-pay'}

# %%
df4=df3.replace(' ?',np.nan)
df4.isnull().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# c_gain               0
# c-loss               0
# hrs_wk               0
# country            857
# income               0
# dtype: int64

# %%
df5=df4.dropna().reset_index()
df5.isnull().sum() # Recheck
# Out:
# index             0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# c_gain            0
# c-loss            0
# hrs_wk            0
# country           0
# income            0
# dtype: int64

# %%
df5.shape # Recheck ..matches with the data description provided
# Out:
# (45222, 16)

# %%
df5.head(2) # Eyeball the cleaned data-set
# Out:
#    index  age          workclass  fnlwgt   education  education_num  \
# 0      0   39          State-gov   77516   Bachelors             13
# 1      1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital_status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    c_gain  c-loss  hrs_wk         country  income
# 0    2174       0      40   United-States   <=50K
# 1       0       0      13   United-States   <=50K

# %%
df5.dtypes # Revisiting the data structure of the cleaned dataset
# Out:
# index              int64
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# c_gain             int64
# c-loss             int64
# hrs_wk             int64
# country           object
# income            object
# dtype: object

# %%
# Now the data-set is cleaned of Junk ,and there is no Null-Values

# %%
# Cleaning the DV of 4 types of objects --and converting to 2

# %%
set(df5.income)
# Out:
# {' <=50K', ' <=50K.', ' >50K', ' >50K.'}

# %%
# Converting DV into 2 classes by removing the extra objects 
df5.loc[df5["income"] == ' <=50K',"income"]=0
df5.loc[df5["income"]==' <=50K.',"income"]=0
df5.loc[df5["income"]==' >50K',"income"]=1
df5.loc[df5["income"]==' >50K.',"income"]=1

# %%
set(df5.income) # Recheck
# Out:
# {0, 1}

# %%
df5.head(2) # Recheck
# Out:
#    index  age          workclass  fnlwgt   education  education_num  \
# 0      0   39          State-gov   77516   Bachelors             13
# 1      1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital_status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    c_gain  c-loss  hrs_wk         country  income
# 0    2174       0      40   United-States       0
# 1       0       0      13   United-States       0

# %%
# Now the data set is completely cleaned -IVs and DV

# %%
# Next step is to perform EDA to understand the dataset better 
# Univariate
# Bivariate
# Multivariate
# Tables -Crosstabs/Pivot tables

# %%
# Libraries for EDA 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
# Plotting the distribution of  WHOLE DATASET (CATEGORICAL & NUMERIC) ..UNIVARIATE 
def plot_distribution(df5, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(df5.shape[1]) / cols)
    for i, column in enumerate(df5.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if df5.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=df5)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            g = sns.distplot(df5[column])
            plt.xticks(rotation=25)
    
plot_distribution(df5, cols=3, width=20, height=20, hspace=0.45, wspace=0.5)

# %%
# Key Obs 
# Age is positive Skewed 
# Dominated by White Population/HS-graduation and above/Working in Private firms with~9 yrs of education
# Married  followed by Single/Divorced
#Higher proportions of Males/Husband
# Dataset is dominated by representations from USA

# %%
# Effect of Marital Status and Education on Income, across Marital Status.

plt.style.use('seaborn-whitegrid')
g = sns.FacetGrid(df5, col='marital_status', size=6, aspect=.7)
g = g.map(sns.boxplot, 'income', 'education_num')
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
###Effect of Workclass & Hr-week on income across Workclass  

df5.columns
plt.style.use('seaborn-whitegrid')
g = sns.FacetGrid(df5, col='workclass', size=4, aspect=.7)
g = g.map(sns.boxplot, 'income', 'hrs_wk')
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Historical Trends on the Sex, Education,and their impact on Income.
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(20,4)) 
plt.subplot(1, 3,1)
sns.violinplot(x='sex', y='education_num', hue='income', data=df5, split=True, scale='count');

plt.subplot(1, 3,2)
sns.violinplot(x='sex', y='hrs_wk', hue='income', data=df5, split=True, scale='count');

# %%
# Historical Trends on the race, capital_gain,and their impact on Income.
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(20,4)) 
plt.subplot(1, 3,1)
sns.violinplot(x='race', y='c_gain', hue='income', data=df5, split=True, scale='count');

# %% [markdown]
# sns.pairplot(df5[['age','education_num','hrs_wk','income','c_gain','c-loss']],
#              hue="income",
#              diag_kind="kde",
#              size=4);

# %%
# Interaction between pairs of features.
sns.pairplot(df5[['age','education_num','hrs_wk','income','c_gain','c-loss']], 
             hue="income", 
             diag_kind="kde",
             size=4);
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\joydeep\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\joydeep\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
df5.columns
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income'],
#       dtype='object')

# %%
corr=df5.iloc[:,[3,5,11,12,13]].corr()
plt.figure(figsize=(7,7))
sns.heatmap(corr,cbar=True,square=True,cmap="coolwarm")

# %%
corr=df5.iloc[:,[3,5,11,12,13]].corr()
corr
# Out:
#                  fnlwgt  education_num    c_gain    c-loss    hrs_wk
# fnlwgt         1.000000      -0.041993 -0.004110 -0.004349 -0.018679
# education_num -0.041993       1.000000  0.126907  0.081711  0.146206
# c_gain        -0.004110       0.126907  1.000000 -0.032102  0.083880
# c-loss        -0.004349       0.081711 -0.032102  1.000000  0.054195
# hrs_wk        -0.018679       0.146206  0.083880  0.054195  1.000000

# %%
# Key Obs : Numeric IVs are not correlated with each other ..they are fairly independent

# %%
df5.dtypes
# Out:
# index              int64
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# c_gain             int64
# c-loss             int64
# hrs_wk             int64
# country           object
# income             int64
# dtype: object

# %%
sns.kdeplot(df5.hrs_wk,shade=True)

# %%
sns.jointplot(df5.hrs_wk,df5.education_num,df5,kind="hex",color="blue")

# %%
pd.crosstab(df5.income,df5.workclass).plot(kind="bar",stacked=True)

# %%
pd.crosstab(df5.income,df5.race).plot(kind="bar",stacked=True)

# %%
pd.crosstab(df5.income,df5.occupation).plot(kind="bar",stacked=True)

# %%
df5.pivot_table(values="hrs_wk",columns=["workclass"])
# Out:
# workclass   Federal-gov   Local-gov    Private   Self-emp-inc  \
# hrs_wk        41.433144   40.865484  40.258925      48.578372
#
# workclass   Self-emp-not-inc   State-gov   Without-pay
# hrs_wk             44.429136   39.121788     33.952381

# %%
df5.pivot_table(values="c_gain",columns=["workclass"])
# Out:
# workclass   Federal-gov   Local-gov     Private   Self-emp-inc  \
# c_gain       924.485064  766.129032  886.123127    5053.619077
#
# workclass   Self-emp-not-inc   State-gov   Without-pay
# c_gain           1800.606955  750.135149    325.238095

# %%
# Key Obs : Self employed has highest( hrs_wk and c_gain)

# %%
# EDA ...In Sum

# %%
### Feature Engineering ====================================================

# %%
# Explore the existing features...Categorical Features ..
sns.countplot(y="workclass",data=df5)# Dominated by Private sector

# %%
sns.countplot(y="race",data=df5)

# %%
sns.countplot(y="education",data=df5)# Some college,HS=grad,Bachelors are well represented

# %%
sns.countplot(y="sex",data=df5)

# %%
sns.countplot(y="marital_status",data=df5)# Married, Single ,divorced well represented

# %%
# New Categorical Feature ..1
df5["Relationship_marital_status"]=df5["relationship"]+df5["marital_status"]

# %%
sns.countplot(y="Relationship_marital_status",data=df5)

# %%
# New Categorical Feature ..2
df5["Race_workclass"]=df5["race"]+df5["workclass"]

# %%
sns.countplot(y="Race_workclass",data=df5)# White private dominates

# %%
df5.columns# 2 new categorical features are added into the dataset
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass'],
#       dtype='object')

# %%
### Feature Engineering =Numerical Features ===================================================

## Exploring and adding new Numerical features 
## check statistical significance of existing features

# %%
##ANOVA TESTING ON EXISTING FEATURES 
## ANOVA : Ho : Mean of group1=Mean ofgroup2=Mean ofgroup3 ....No significant relationship between means
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
mod = ols('c_gain~income',data=df5).fit()

# %%
aov_table = sm.stats.anova_lm(mod, typ=2)# As p values of Fstatistic is less than 0.05
print(aov_table) # and conclude that there is a significant difference between means of 
# capital gains and income
# Out:
#                 sum_sq       df          F  PR(>F)
# income    1.244871e+11      1.0  2322.7457     0.0
# Residual  2.423558e+12  45220.0        NaN     NaN

# %%
df_sub1=df5[["c_gain","income"]]#Eye the means

# %%
m1=df_sub1.groupby("income").mean()

# %%
m1 # Reconfirmation ..Here we see that there is a significant difference
# Out:
#              c_gain
# income
# 0        149.023402
# 1       3991.791667

# %%
mod = ols('fnlwgt~income',data=df5).fit()

# %%
df5.columns
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass'],
#       dtype='object')

# %%
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)# Given that p-value of Fstatistic is >0.05 therefore we accept the Null Hypothesis
# Out:
#                 sum_sq       df         F    PR(>F)
# income    2.662757e+10      1.0  2.386133  0.122423
# Residual  5.046234e+14  45220.0       NaN       NaN

# %%
df_sub1=df5[["fnlwgt","income"]]#Eye the means

# %%
m1=df_sub1.groupby("income").mean()

# %%
m1# Recheck that there is no significant difference
# Out:
#                fnlwgt
# income
# 0       190175.214235
# 1       188397.967345

# %%
# Summarizing the findings of Anova on existing features 
# C-Gain : Reject HO ,and conclude that there is significant relationship between Income $ C_gain
#fnlwgt : Accept HO ,and conclude that there is no significant relationship between income and fnlwgt

# %%
##New Feature Creation and testing for significance using ANOVA

# %%
df5.head(1)
# Out:
#    index  age   workclass  fnlwgt   education  education_num  marital_status  \
# 0      0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship    race    sex  c_gain  c-loss  hrs_wk  \
# 0   Adm-clerical   Not-in-family   White   Male    2174       0      40
#
#           country  income   Relationship_marital_status    Race_workclass
# 0   United-States       0   Not-in-family Never-married   White State-gov

# %%
####Creating feature3 and testing with ANOVA for statistical significance..(C_gain /hrs_wk)

df5["feature3"]=df5["c_gain"]/df5["hrs_wk"]

# %%
df5.columns
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass', 'feature3'],
#       dtype='object')

# %%
df5.dtypes
# Out:
# index                            int64
# age                              int64
# workclass                       object
# fnlwgt                           int64
# education                       object
# education_num                    int64
# marital_status                  object
# occupation                      object
# relationship                    object
# race                            object
# sex                             object
# c_gain                           int64
# c-loss                           int64
# hrs_wk                           int64
# country                         object
# income                           int64
# Relationship_marital_status     object
# Race_workclass                  object
# feature3                       float64
# dtype: object

# %%
mod = ols('feature3~income',data=df5).fit()

# %%
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                 sum_sq       df            F  PR(>F)
# income    6.161015e+07      1.0  1896.154664     0.0
# Residual  1.469295e+09  45220.0          NaN     NaN

# %%
###Creating feature 4 and testing with ANOVA for statistical significance..(Age /hrs_wk)

# %%
df5["feature4"]=df5["age"]/df5["hrs_wk"]

# %%
mod = ols('feature4~income',data=df5).fit()

# %%
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                 sum_sq       df         F    PR(>F)
# income       13.384959      1.0  6.623121  0.010069
# Residual  91387.095245  45220.0       NaN       NaN

# %%
###Creating feature 5 and testing with ANOVA for statistical significance..Age/educ_num

# %%
df5["feature5"]=df5["age"]/df5["education_num"]

# %%
mod = ols('feature5~income',data=df5).fit()

# %%
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                  sum_sq       df          F        PR(>F)
# income       841.506745      1.0  85.584956  2.313360e-20
# Residual  444621.774111  45220.0        NaN           NaN

# %%
# Rechecking Means for Feature 4,& 5

# %%
df_sub4=df5[["feature4","income"]]

# %%
c=df_sub4.groupby("income").mean()

# %%
c
# Out:
#         feature4
# income
# 0       1.112831
# 1       1.072984

# %%
df_sub5=df5[["feature5","income"]]

# %%
d=df_sub5.groupby("income").mean()

# %%
d
# Out:
#         feature5
# income
# 0       4.339947
# 1       4.024003

# %%
## Key Observations --Feature creation and Anova Testing 
# FEATURE 3,4,5 created and testing for statistical significance using Anova(Fstat)
## and found to be significant wrt to Dependent variavle (income)..therefore we will retain

# %%
df5.columns
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass', 'feature3', 'feature4', 'feature5'],
#       dtype='object')

# %%
df5.shape# 2 categorical features and 3 numerical features  created and added to datset
# Out:
# (45222, 21)

# %%
## Feature Binning of Numerical =======Given high skews of numerical IVs

# %%
df5.feature5.skew()
# Out:
# 6.588138659406053

# %%
df5.feature4.skew()
# Out:
# 22.141978807858056

# %%
df5.feature3.skew()
# Out:
# 18.47353989486372

# %%
df5.age.skew()
# Out:
# 0.5328158942555792

# %%
df5.hrs_wk.skew()
# Out:
# 0.34054514378520867

# %%
df5.c_gain.skew()
# Out:
# 11.789002180291192

# %%
df5["age"]=pd.cut(df5["age"],10)

# %%
df5["fnlwgt"]=pd.cut(df5["fnlwgt"],10)

# %%
df5["hrs_wk"]=pd.cut(df5["hrs_wk"],10)

# %%
df5["education_num"]=pd.cut(df5["education_num"],10)

# %%
df5["c_gain"]=pd.cut(df5["c_gain"],10)

# %%
df5["c-loss"]=pd.cut(df5["c-loss"],10)

# %%
df5["feature3"]=pd.cut(df5["feature3"],10)

# %%
df5["feature4"]=pd.cut(df5["feature4"],10)

# %%
df5["feature5"]=pd.cut(df5["feature5"],10)

# %%
## Recheck the binned dataset

# %%
df5.head(2)
# Out:
#    index           age          workclass                 fnlwgt   education  \
# 0      0  (38.9, 46.2]          State-gov  (12015.092, 161182.8]   Bachelors
# 1      1  (46.2, 53.5]   Self-emp-not-inc  (12015.092, 161182.8]   Bachelors
#
#   education_num       marital_status        occupation    relationship  \
# 0  (11.5, 13.0]        Never-married      Adm-clerical   Not-in-family
# 1  (11.5, 13.0]   Married-civ-spouse   Exec-managerial         Husband
#
#      race  ...             c_gain           c-loss        hrs_wk  \
# 0   White  ...  (-99.999, 9999.9]  (-4.356, 435.6]  (30.4, 40.2]
# 1   White  ...  (-99.999, 9999.9]  (-4.356, 435.6]  (10.8, 20.6]
#
#           country income   Relationship_marital_status  \
# 0   United-States      0   Not-in-family Never-married
# 1   United-States      0    Husband Married-civ-spouse
#
#             Race_workclass           feature3        feature4       feature5
# ...

# %%
set(df5.age)# Recheck
# Out:
# {Interval(16.927, 24.3, closed='right'),
#  Interval(24.3, 31.6, closed='right'),
#  Interval(31.6, 38.9, closed='right'),
#  Interval(38.9, 46.2, closed='right'),
#  Interval(46.2, 53.5, closed='right'),
#  Interval(53.5, 60.8, closed='right'),
#  Interval(60.8, 68.1, closed='right'),
#  Interval(68.1, 75.4, closed='right'),
#  Interval(75.4, 82.7, closed='right'),
#  Interval(82.7, 90.0, closed='right')}

# %%
# Plotting the binned columns

# %%
sns.countplot(y="age",data=df5)#We can combine last 3 bins for better class balance

# %%
sns.countplot(y="fnlwgt",data=df5)# we can combine last 7 bins for better class balance

# %%
sns.countplot(y="hrs_wk",data=df5)# we can combine last3 bins for better class balance

# %%
sns.countplot(y="c_gain",data=df5)# class imbalance

# %%
sns.countplot(y="c-loss",data=df5)# class imbalance

# %%
sns.countplot(y="feature3",data=df5)# class imbalance

# %%
sns.countplot(y="feature4",data=df5)# class imbalance

# %%
sns.countplot(y="feature5",data=df5)

# %%
# Key conclusion --Feature Creation/Significance /Binning
# Using EDA ,we created Features,Tested for significance using ANOVA,Binned the features

# %%
# Handling class imbalance ---Categorical & Binned Categorical Variables

# %%
df5.columns
# Out:
# Index(['index', 'age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass', 'feature3', 'feature4', 'feature5'],
#       dtype='object')

# %%
data=df5.drop(['index'],axis=1)

# %%
data.head(1)
# Out:
#             age   workclass                 fnlwgt   education education_num  \
# 0  (38.9, 46.2]   State-gov  (12015.092, 161182.8]   Bachelors  (11.5, 13.0]
#
#    marital_status     occupation    relationship    race    sex  \
# 0   Never-married   Adm-clerical   Not-in-family   White   Male
#
#               c_gain           c-loss        hrs_wk         country  income  \
# 0  (-99.999, 9999.9]  (-4.356, 435.6]  (30.4, 40.2]   United-States       0
#
#     Relationship_marital_status    Race_workclass           feature3  \
# 0   Not-in-family Never-married   White State-gov  (-11.365, 1136.5]
#
#          feature4       feature5
# 0  (0.115, 7.873]  (1.21, 8.857]

# %%
data.dtypes
# Out:
# age                            category
# workclass                        object
# fnlwgt                         category
# education                        object
# education_num                  category
# marital_status                   object
# occupation                       object
# relationship                     object
# race                             object
# sex                              object
# c_gain                         category
# c-loss                         category
# hrs_wk                         category
# country                          object
# income                            int64
# Relationship_marital_status      object
# Race_workclass                   object
# feature3                       category
# feature4                       category
# feature5                       category
# dtype: object

# %%
# Assign all columns to numeric values using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'income', 'Relationship_marital_status',
#        'Race_workclass', 'feature3', 'feature4', 'feature5'],
#       dtype='object')

# %%
categorical_features=["age","workclass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","c_gain","c-loss","hrs_wk","country","income",'Relationship_marital_status','Race_workclass','feature3',"feature4","feature5"]

# %%
data.shape
# Out:
# (45222, 20)

# %%
le=LabelEncoder()

# %%
for i in range(20):
    new=le.fit_transform(data[categorical_features[i]])
    data[categorical_features[i]]=new

# %%
data.head(2)
df5.head(2)
# Out:
#    index           age          workclass                 fnlwgt   education  \
# 0      0  (38.9, 46.2]          State-gov  (12015.092, 161182.8]   Bachelors
# 1      1  (46.2, 53.5]   Self-emp-not-inc  (12015.092, 161182.8]   Bachelors
#
#   education_num       marital_status        occupation    relationship  \
# 0  (11.5, 13.0]        Never-married      Adm-clerical   Not-in-family
# 1  (11.5, 13.0]   Married-civ-spouse   Exec-managerial         Husband
#
#      race  ...             c_gain           c-loss        hrs_wk  \
# 0   White  ...  (-99.999, 9999.9]  (-4.356, 435.6]  (30.4, 40.2]
# 1   White  ...  (-99.999, 9999.9]  (-4.356, 435.6]  (10.8, 20.6]
#
#           country income   Relationship_marital_status  \
# 0   United-States      0   Not-in-family Never-married
# 1   United-States      0    Husband Married-civ-spouse
#
#             Race_workclass           feature3        feature4       feature5
# ...

# %%
df6=data # Dataset with class imbalance

# %%
df6.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0    3          5       0          9              7               4
# 1    4          4       0          9              7               2
# 2    2          2       1         11              5               0
# 3    4          2       1          1              3               2
# 4    1          2       2          9              7               2
#
#    occupation  relationship  race  sex  c_gain  c-loss  hrs_wk  country  \
# 0           0             1     4    1       0       0       3       38
# 1           3             0     4    1       0       0       1       38
# 2           5             1     4    1       0       0       3       38
# 3           5             0     2    1       0       0       3       38
# 4           9             5     2    0       0       0       3        4
#
#    income  Relationship_marital_status  Race_workclass  feature3  feature4  \
# ...

# %%
# Rebalancing Age
sns.countplot(y="age",data=df6)

# %%
df6["age"]=df6.replace({9:8,7:6})
sns.countplot(y="age",data=df6)

# %%
sns.countplot(y="age",data=df5)

# %%
# Dataset for modelling 
X=df6.drop(["income"],axis=1)
y=df6["income"]

# %%
X.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0    3          5       0          9              7               4
# 1    4          4       0          9              7               2
# 2    2          2       1         11              5               0
# 3    4          2       1          1              3               2
# 4    1          2       2          9              7               2
#
#    occupation  relationship  race  sex  c_gain  c-loss  hrs_wk  country  \
# 0           0             1     4    1       0       0       3       38
# 1           3             0     4    1       0       0       1       38
# 2           5             1     4    1       0       0       3       38
# 3           5             0     2    1       0       0       3       38
# 4           9             5     2    0       0       0       3        4
#
#    Relationship_marital_status  Race_workclass  feature3  feature4  feature5
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
X.shape
# Out:
# (45222, 19)

# %%
y.shape
# Out:
# (45222,)

# %%
# Summary: Dataset for modelling 
# IVs =19, Obs=45222
# DV=1, Obs=45222

# %%
# Preparing the dataset for modelling ..DATA TRANSFORMATION 
# Given that we will be using Linear and Non-Linear Algorithms therefore we will 
# transform the data  with two methods 
# Standardize the data(mean=0,std=1, Algos assuming Gaussian Dist -Logistic Regression,LDA)
# Normalize the Data(KNN with distance measures )

# %%
#Libraries:
from sklearn.preprocessing import StandardScaler,Normalizer

# %%
scaler=Normalizer().fit(X)
Norm_X=scaler.transform(X)

# %%
Scaler2=StandardScaler().fit(X)
Rescaled_X=Scaler2.transform(X)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\joydeep\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.

# %%
print(Rescaled_X[0:2,:])
# Out:
# [[ 0.31105265  2.9177173  -0.97928634 -0.34407409  0.97918814  0.94293603
#   -1.48262433 -0.25838652  0.38411021  0.69381348 -0.1209036  -0.21708494
#   -0.22621236  0.26299899 -0.36394164  0.87469094 -0.06817025 -0.05253139
#   -0.17520323]
#  [ 0.87227285  1.87399717 -0.97928634 -0.34407409  0.97918814 -0.3900051
#   -0.7375336  -0.88447855  0.38411021  0.69381348 -0.1209036  -0.21708494
#   -1.73569668  0.26299899 -0.79673813  0.69560246 -0.06817025 -0.05253139
#   -0.17520323]]

# %%
print(Norm_X[0:2,:])
# Out:
# [[0.05842062 0.09736771 0.         0.17526187 0.13631479 0.07789417
#   0.         0.01947354 0.07789417 0.01947354 0.         0.
#   0.05842062 0.73999457 0.09736771 0.60367978 0.         0.
#   0.        ]
#  [0.07939884 0.07939884 0.         0.1786474  0.13894798 0.03969942
#   0.05954913 0.         0.07939884 0.01984971 0.         0.
#   0.01984971 0.75428902 0.01984971 0.59549133 0.         0.
#   0.        ]]

# %%
print(X.values[0:2,:])
# Out:
# [[ 3  5  0  9  7  4  0  1  4  1  0  0  3 38  5 31  0  0  0]
#  [ 4  4  0  9  7  2  3  0  4  1  0  0  1 38  1 30  0  0  0]]

# %%
# Summarizing DataTransformation 
# 2 TRANSFORMATION KEPT READY --Norm_X,Rescaled_X
# We have 3 feature matrix--X,Norn_X,Rescaled_X

# %%
# FEATURE SELECTION 
# Two methods -RFE(Recursive Feature Elimination & Feature Importance through Ensemble)

# %%
# Libraries 
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier

# %%
#model=ExtraTreesClassifier()
#model.fit(X,y)
print(model.feature_importances_)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.10766026 0.03679738 0.06220802 0.05019016 0.11077833 0.07293158
#  0.11514652 0.0787168  0.01032546 0.0256096  0.05533279 0.03269573
#  0.09209472 0.02335671 0.0810746  0.03572159 0.00402057 0.00127272
#  0.00406647]

# %%
#Visualizing Feature Selection
d=pd.DataFrame(model.feature_importances_,index=X.columns)
d.head(2)
d.plot(kind="bar")

# %%
# Education_num , Occupation ,Relationship are identified as top two features

# %%
lr=LogisticRegression()
rfe=RFE(lr,3)
fit=rfe.fit(X,y)
print(fit.n_features_,"",fit.support_,"",fit.ranking_)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
X.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex', 'c_gain',
#        'c-loss', 'hrs_wk', 'country', 'Relationship_marital_status',
#        'Race_workclass', 'feature3', 'feature4', 'feature5'],
#       dtype='object')

# %%
# Age,Workclass,C_gain are identifed as most imp features

# %%
# Dataset Split 
# Check the  efficacy of train/test/split
# Check the efficacy of Resampling using Kfold cross-validation

# %%
# Libraries to be downloaded

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)# cross check
# Out:
# (31655, 19) (13567, 19) (31655,) (13567,)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
lr.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8205970620755015

# %%
lr.score(X_test,y_test)
# Out:
# 0.8220682538512567

# %%
Kfold=KFold(n_splits=10,random_state=7)
lr=LogisticRegression()
result=cross_val_score(lr,X_train,y_train,cv=10)
print(result,result.mean(),result.std())
result1=cross_val_score(lr,X_test,y_test,cv=10)
print(result1.mean())
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
Kfold=KFold(n_splits=10,random_state=7)
lr=LogisticRegression()
result=cross_val_score(lr,Norm_X,y,cv=10)
print(result,result.mean(),result.std())
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
Kfold=KFold(n_splits=10,random_state=7)
lr=LogisticRegression()
result=cross_val_score(lr,Rescaled_X,y,cv=10)
print(result,result.mean(),result.std())
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
# Key Conclusions : Train/Test Split & KFOLD resampling gives similar scores on X &y..
# Given large observations the bias is taken care of .. 
# However on transformed data -KFold gives better score on standardized scale as against Normalized scale

# %%
# Machine learning 
import sklearn.ensemble as ske
from sklearn import datasets, model_selection, tree, preprocessing, metrics, linear_model
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# Grid and Random Search
import scipy.stats as st
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
#Metrics
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc

# %%
# Machine Learning Algo + Boosting+Bagging+Gridsearch(PARAMETER OPTIMISATION)

# %%
# lOGISTIC REGRSSION..
# 3 MODELS...
# MODEL 1-LR
# MODEL2-LR with GRID SEARCH
# MODEL3-LR with PENALTY

model1=LogisticRegression()
model1.fit(X_train,y_train)
model1.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8205970620755015

# %%
model1.score(X_test,y_test)
# Out:
# 0.8220682538512567

# %%
# Gridsearch on Logistic Regression
model_GS=LogisticRegression()
param_grid={"C":[0.001,0.005,0.05,0.1,.05,1.0,0.25],"solver":["newton-cg","lbfgs","liblinear"]}
gridLogistic=GridSearchCV(model_GS,param_grid,cv=10)

# %%
gridLogistic.fit(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
# ...

# %%
gridLogistic.best_params_
# Out:
# {'C': 1.0, 'solver': 'liblinear'}

# %%
model2=LogisticRegression(C=0.1,solver="liblinear")# Logistic Regression with GridSearch

# %%
model2.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model2.score(X_train,y_train)
# Out:
# 0.8205654714894961

# %%
model2.score(X_test,y_test)
# Out:
# 0.8232475860543967

# %%
# Logistic Regression with Penalty 
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso, SGDClassifier

# %%
model3=LogisticRegression(penalty="l1",max_iter=1000,random_state=7)
model3.fit(X_train,y_train)
model3.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8206602432475122

# %%
model3.score(X_test,y_test)
# Out:
# 0.8222893786393455

# %%
#Final Model for Logistic Regression : model2 (gridsearch with parameter optimisation)

# %%
# LINEAR DISCRIMINANT ANALYSIS

model4=LinearDiscriminantAnalysis()
model4.fit(X_train,y_train)
model4.score(X_train,y_train)
# Out:
# 0.8197757068393619

# %%
model4.score(X_test,y_test)
# Out:
# 0.820962629910813

# %%
# Non Linear Models--Decision Tree,Naive Bayes,SVM

# %%
# DECISION TREE
# Model 5
# Model6-GridSearch

# %%
model5=DecisionTreeClassifier()
model5.fit(X_train,y_train)
model5.score(X_train,y_train)
model5.score(X_test,y_test)
# Out:
# 0.8005454411439522

# %%
# DECISION TREE WITH GRID-SEARCH
param_grid={"criterion":["gini","entropy"],"min_samples_split":[10,20,30,40],"max_depth":[2,3,4,6],"min_samples_leaf":[10,20,30]}

# %%
DT_GS=DecisionTreeClassifier()
grid=GridSearchCV(DT_GS,param_grid,cv=10)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['gini', 'entropy'], 'min_samples_split': [10, 20, 30, 40], 'max_depth': [2, 3, 4, 6], 'min_samples_leaf': [10, 20, 30]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_leaf': 20,
#  'min_samples_split': 10}

# %%
model6=DecisionTreeClassifier(criterion="gini",max_depth=6,min_samples_leaf=10,min_samples_split=30)

# %%
model6.fit(X_train,y_train)
model6.score(X_train,y_train)
# Out:
# 0.834623282261886

# %%
model6.score(X_test,y_test)
# Out:
# 0.8351883246111889

# %%
# K NEIGHBORS CLASSIFIER

model7=KNeighborsClassifier()
model7.fit(X_train,y_train)
model7.score(X_train,y_train)
# Out:
# 0.8627073132206602

# %%
model7.score(X_test,y_test)
# Out:
# 0.817424633301393

# %%
# NAIVE-BAYES

model8=GaussianNB()
model8.fit(X_train,y_train)
model8.score(X_train,y_train)
# Out:
# 0.7850260622334544

# %%
model8.score(X_test,y_test)
# Out:
# 0.7875727869094126

# %%
#SUPPORT VECTOR MACHINES
#Model9-SVM
#Model10-SVM with GridSearch
model9=SVC()
model9.fit(X_train,y_train)
model9.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.8574948665297741

# %%
model9.score(X_test,y_test)
# Out:
# 0.8375469890174688

# %%
# Model10 -SVM withGridSearch 
param_grid = {'kernel': ['linear', 'rbf','poly'], 'C':[1.5, 10],'gamma': [1e-7, 1e-4]}
svr_grid=SVC()
grid = GridSearchCV(svr_grid, param_grid)
grid.fit(X_train,y_train)
grid.best_params_
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'C': 10, 'gamma': 1e-07, 'kernel': 'linear'}

# %%
model10=SVC(C=10,gamma=1e-07,kernel="linear")

# %%
model10.fit(X_train,y_train)
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1e-07, kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model10.score(X_train,y_train)
# Out:
# 0.8206918338335176

# %%
model10.score(X_test,y_test)
# Out:
# 0.8245006265202329

# %%
# NON-LINEAR ENSEMBLE MODEL-RANDOM FOREST 
# MODEL11-Random Forest
# Model 12-GRID_SEARCH RANDOM FOREST
model11=RandomForestClassifier()
model11.fit(X_train,y_train)
model11.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9350497551729584

# %%
model11.score(X_test,y_test)
# Out:
# 0.8243532099948404

# %%
# Random Forest with Grid Search 
param_grid2={"criterion":["gini","entropy"],"max_features":[3,4,5,7],"max_depth":[2,3,4,6],"n_estimators":[10,20,30,40,50,70,100]}

# %%
RF_GRID=RandomForestClassifier()
Grid=GridSearchCV(RF_GRID,param_grid2,cv=10)

# %%
Grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['gini', 'entropy'], 'max_features': [3, 4, 5, 7], 'max_depth': [2, 3, 4, 6], 'n_estimators': [10, 20, 30, 40, 50, 70, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
Grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 6, 'max_features': 7, 'n_estimators': 100}

# %%
model12=RandomForestClassifier(criterion="gini",max_depth=7,n_estimators=100)
model12.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
model12.score(X_train,y_train)
# Out:
# 0.8380034749644606

# %%
model12.score(X_test,y_test)
# Out:
# 0.8379892385936464

# %%
#NON-LINEAR ENSEMBLE MODEL-ADA BOOST CLASSIFIER 
# MODEL13-Ada Boost Classifier

# %%
model13=AdaBoostClassifier()

# %%
model13.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
model13.score(X_train,y_train)
# Out:
# 0.8425841099352392

# %%
model13.score(X_test,y_test)
# Out:
# 0.8454337731259675

# %%
param5={"learning_rate":[1.0,0.2,0.4,0.6,0.8],"n_estimators":[50,60,70,80,90,100]}

# %%
AB_GRID=AdaBoostClassifier()
Grid=GridSearchCV(AB_GRID,param5,cv=10)
Grid.fit(X_train,y_train)
Grid.best_params_
# Out:
# {'learning_rate': 0.8, 'n_estimators': 100}

# %%
model14=AdaBoostClassifier(learning_rate=0.8,n_estimators=100)

# %%
model14.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=0.8, n_estimators=100, random_state=None)

# %%
model14.score(X_test,y_test)
# Out:
# 0.8455074813886637

# %%
model14.score(X_train,y_train)
# Out:
# 0.8447322697836045

# %%
##NON-LINEAR ENSEMBLE MODEL-GRADIENT BOOSTING CLASSIFIER
 #MODEL15-Gradient Boosting Classifier
# MODEL16-Gradient Boosting Classifier with Grid Search

# %%
model15=GradientBoostingClassifier()
model15.fit(X_train,y_train)
model15.score(X_train,y_train)
# Out:
# 0.8490285894803349

# %%
model15.score(X_test,y_test)
# Out:
# 0.8474238962187661

# %%
# Gradient Boosting Classifier with Grid Search --Model 16

# %%
param_grid10={"max_features":[3,5,7],"max_depth":[3,4,6],"n_estimators":[100,200,300]}

# %%
GBC_GRID=GradientBoostingClassifier()
Grid=GridSearchCV(GBC_GRID,param_grid10,cv=10)

# %%
Grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_sampl...      subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_features': [3, 5, 7], 'max_depth': [3, 4, 6], 'n_estimators': [100, 200, 300]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
model16=GradientBoostingClassifier(max_depth=5,max_features=4,n_estimators=200)

# %%
model16.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=5,
#               max_features=4, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=200,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
model16.score(X_train,y_train)
# Out:
# 0.8629600379087032

# %%
model16.score(X_test,y_test)
# Out:
# 0.8514041424043636

# %%
# And finally VOTING ENSEMBLE
# Model17-Voting Ensembles

# %%
from sklearn.ensemble import VotingClassifier

# %%
kfold=KFold(n_splits=10,random_state=7)

# %%
estimator=[]
model1=LogisticRegression()
estimator.append(("logistic",model1))

# %%
model2=DecisionTreeClassifier()
estimator.append(("cart",model2))

# %%
model3=LinearDiscriminantAnalysis()
estimator.append(("lda",model3))

# %%
model4=SVC()
estimator.append(("svm",model4))

# %%
estimator
# Out:
# [('logistic',
#   LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#             intercept_scaling=1, max_iter=100, multi_class='warn',
#             n_jobs=None, penalty='l2', random_state=None, solver='warn',
#             tol=0.0001, verbose=0, warm_start=False)),
#  ('cart',
#   DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#               splitter='best')),
#  ('lda',
#   LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                 solver='svd', store_covariance=False, tol=0.0001)),
#  ('svm', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
# ...

# %%
ensemble=VotingClassifier(estimator)
ensemble.fit(X_train,y_train)
ensemble.score(X_train,y_train)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.8415416205970621

# %%
ensemble.score(X_test,y_test)
# Out:
# 0.8261222082995504

# %%
result=cross_val_score(ensemble,X_test,y_test,cv=10)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
result.mean()
# Out:
# 0.8259018027359503

# %%
####PREDICTION

## SCORE--Accuracy
##CONFUSION MATRIX--Alpha & Beta Error
###CLASSIFICATION REPORT-Precision --F1 score 
####ROC-Curves--AUC

# %%
# Accuracy scores of 17 models
model1.fit(X_train,y_train)
predicted1=model1.predict(X_test)
print("LR accuracy",metrics.accuracy_score(predicted1,y_test))
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LR accuracy 0.8220682538512567

# %%
model2.fit(X_train,y_train)
predicted2=model2.predict(X_test)
print("LR_Grid accuracy",metrics.accuracy_score(predicted2,y_test))
# Out:
# LR_Grid accuracy 0.8003243163558635

# %%
model3.fit(X_train,y_train)
predicted3=model3.predict(X_test)
print("LR_Penalty Accuracy ",metrics.accuracy_score(predicted3,y_test))
# Out:
# LR_Penalty Accuracy  0.820962629910813

# %%
model4.fit(X_train,y_train)
predicted4=model4.predict(X_test)
print("LDA_ Accuracy ",metrics.accuracy_score(predicted4,y_test))
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# LDA_ Accuracy  0.8375469890174688

# %%
### NON-LINEAR MODELS
predicted5=model5.predict(X_test)
print("DECISION TREE ",metrics.accuracy_score(predicted5,y_test))
predicted6=model6.predict(X_test)
print("DECISION TREE+GRID SEARCH ",metrics.accuracy_score(predicted6,y_test))
predicted7=model7.predict(X_test)
print("KNN ",metrics.accuracy_score(predicted7,y_test))
predicted8=model8.predict(X_test)
print("NAIVE_BAYES ",metrics.accuracy_score(predicted8,y_test))
predicted9=model9.predict(X_test)
print("SUPPORT VECTOR ",metrics.accuracy_score(predicted9,y_test))
model10.fit(X_train,y_train)
predicted10=model10.predict(X_test)
print("SUPPORT VECTOR+GRID SEARCH ",metrics.accuracy_score(predicted10,y_test))
# Out:
# DECISION TREE  0.8005454411439522
# DECISION TREE+GRID SEARCH  0.8351883246111889
# KNN  0.817424633301393
# NAIVE_BAYES  0.7875727869094126
# SUPPORT VECTOR  0.8375469890174688
# SUPPORT VECTOR+GRID SEARCH  0.8245006265202329

# %%
#ENSEMBLE MODELS 
predicted11=model11.predict(X_test)
print("RANDOM FOREST Accuracy ",metrics.accuracy_score(predicted11,y_test))
predicted12=model12.predict(X_test)
print("RANDOM FOREST+GRID Accuracy ",metrics.accuracy_score(predicted12,y_test))
predicted13=model13.predict(X_test)
print("AdaBoostClassifier  Accuracy",metrics.accuracy_score(predicted13,y_test))
predicted14=model14.predict(X_test)
print("AdaBoostClassifier+Grid Accuracy",metrics.accuracy_score(predicted14,y_test))
predicted15=model15.predict(X_test)
print("GradientBoostingClassifier Accuracy",metrics.accuracy_score(predicted15,y_test))
predicted16=model16.predict(X_test)
print("GradientBoostingClassifier+GRID Accuracy",metrics.accuracy_score(predicted16,y_test))
# Out:
# RANDOM FOREST Accuracy  0.8243532099948404
# RANDOM FOREST+GRID Accuracy  0.8379892385936464
# AdaBoostClassifier  Accuracy 0.8454337731259675
# AdaBoostClassifier+Grid Accuracy 0.8455074813886637
# GradientBoostingClassifier Accuracy 0.8474238962187661
# GradientBoostingClassifier+GRID Accuracy 0.8514041424043636

# %%
#CLASSIFICATION REPORT 
from sklearn.metrics import classification_report

report1=classification_report(y_test,predicted1)
report2=classification_report(y_test,predicted2)
report3=classification_report(y_test,predicted3)
report4=classification_report(y_test,predicted4)
report5=classification_report(y_test,predicted5)
report6=classification_report(y_test,predicted6)
report7=classification_report(y_test,predicted7)
report8=classification_report(y_test,predicted8)
report9=classification_report(y_test,predicted9)
report10=classification_report(y_test,predicted10)
report11=classification_report(y_test,predicted11)
report12=classification_report(y_test,predicted12)
report13=classification_report(y_test,predicted13)
report14=classification_report(y_test,predicted14)
report15=classification_report(y_test,predicted15)
report16=classification_report(y_test,predicted16)


print("ClassLR",report1)
print("Class_rpt LR+GRID",report2)
print("Class__rpt LR+PENALTY",report3)
print("Class_rept LDA",report4)
print("Class_rept DECISION TREE",report5)
print("Class_rpt DECISION TREE+GRID",report6)
print("Class_rpt KNN",report7)
print("Class_rpt NAIVE_BAYES",report8)
print("Class_rpt SVM",report9)
print("Class_rpt SVM+GRID",report10)
print("Class_rpt RANDOM FOREST",report11)
print("Class_rpt RANDOM FOREST+GRID",report12)
print("Class_rpt AdaBoost",report13)
print("Class_rpt+ADA+GRID",report14)
print("Class_rpt GRAD",report15)
print("Class_rptGRAD+GRID",report16)
# Out:
# ClassLR               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     10230
#            1       0.71      0.46      0.56      3337
#
#    micro avg       0.82      0.82      0.82     13567
#    macro avg       0.78      0.70      0.72     13567
# weighted avg       0.81      0.82      0.81     13567
#
# Class_rpt LR+GRID               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87     10230
#            1       0.60      0.56      0.58      3337
#
#    micro avg       0.80      0.80      0.80     13567
#    macro avg       0.73      0.72      0.73     13567
# weighted avg       0.80      0.80      0.80     13567
#
# Class__rpt LR+PENALTY               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89     10230
#            1       0.71      0.46      0.56      3337
#
#    micro avg       0.82      0.82      0.82     13567
# ...

# %%
# Classification Report -Model17
from sklearn.metrics import classification_report

predicted17=ensemble.predict(X_test)
report=classification_report(y_test,predicted17)
print("Voting",report)
# Out:
# Voting               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89     10230
#            1       0.75      0.44      0.55      3337
#
#    micro avg       0.83      0.83      0.83     13567
#    macro avg       0.80      0.70      0.72     13567
# weighted avg       0.82      0.83      0.81     13567

# %%
### ROC -Curves
# MODEL 1 --LOGISTIC REGRESSION

import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = model1.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic-Model1-LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
## ROC for model2

probs =model14.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic-Model2-LR-Grid')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
## CONFUSION MATRIX 

from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,predicted10)
print(matrix)
# Out:
# [[9755  475]
#  [1906 1431]]

# %%
# Summarizing --Accuracies of Linear,Non-Linear,Ensemble 
#Linear Models --Accuracy 

models = [] 
models.append(('LR', LogisticRegression()))
models.append(("LDA",LinearDiscriminantAnalysis()))
results=[]
names=[]
kfold=KFold(n_splits=10)
num_folds = 10 
seed = 7 
scoring = 'accuracy'
for name, model in models: 
    kfold = KFold(n_splits=num_folds, random_state=seed) 
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring) 
    results.append(cv_results) 
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# Compare Algorithms
fig = plt.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
# Summarizing --Accuracies of Linear,Non-Linear,Ensemble 
#Non-Linear Model --Accuracy 
models = [] 
models.append(('DECISION TREE', DecisionTreeClassifier()))
models.append(("NAIVE_BAYES",GaussianNB()))
models.append(("KNN",KNeighborsClassifier()))
models.append(("SVM",SVC()))

results=[]
names=[]
kfold=KFold(n_splits=10)
num_folds = 10 
seed = 7 
scoring = 'accuracy'
for name, model in models: 
    kfold = KFold(n_splits=num_folds, random_state=seed) 
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring) 
    results.append(cv_results) 
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# Compare Algorithms
fig = plt.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# DECISION TREE: 0.802528 (0.006709)
# NAIVE_BAYES: 0.785374 (0.007668)
# KNN: 0.816017 (0.006563)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# ...

# %%
# Summarizing --Accuracies of Linear,Non-Linear,Ensemble 
#Ensemble  --Accuracy 
models = [] 
models.append(('RANDOM FOREST', RandomForestClassifier()))
models.append(("Grad-Boost",GradientBoostingClassifier()))
models.append(("AdaBoost",AdaBoostClassifier()))


results=[]
names=[]
kfold=KFold(n_splits=10)
num_folds = 10 
seed = 7 
scoring = 'accuracy'
for name, model in models: 
    kfold = KFold(n_splits=num_folds, random_state=seed) 
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring) 
    results.append(cv_results) 
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# Compare Algorithms
fig = plt.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
# Standardize the dataset pipelines = []
from sklearn.pipeline import Pipeline
pipelines=[]
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR', LogisticRegression())]))) 
pipelines.append(('ScaledLDA', Pipeline([('Scaler', StandardScaler()),('LDA', LinearDiscriminantAnalysis())])))
pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('DEC TREE', DecisionTreeClassifier())])))
results = []
names = [] 
for name, model in pipelines:
    kfold = KFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# Out:
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\base.py:465: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\joydeep\Anaconda3\lib\site-packages\sklearn\pipeline.py:331: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# ...

# %%
# Compare Algorithms
fig = plt.figure() 
fig.suptitle('Scaled Algorithm Comparison') 
ax = fig.add_subplot(111) 
plt.boxplot(results)
ax.set_xticklabels(names) 
plt.show()

# %%
# Checking model accuracy using PCA
# Create Ploynomial Features and check model accuracy using PCA

# %%
models = pd.DataFrame({
    'Model':['KNN','Logistic Regression']})

models
# Out:
#                  Model
# 0                  KNN
# 1  Logistic Regression

# %%
# Ranking Results
models = pd.DataFrame({
    'Model': ['KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree', 'Gradient Boosting Trees'],
    'Score': [acc_cv_knn,acc_cv_log,acc_cv_rf,acc_cv_gaussian,acc_cv_sgd,acc_cv_linear_svc,acc_cv_dt,acc_cv_gbt]})
   
models.sort_values(by='Score', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-396-a1b2e69abf97> in <module>
#       5               'Stochastic Gradient Decent', 'Linear SVC',
#       6               'Decision Tree', 'Gradient Boosting Trees'],
# ----> 7     'Score': [acc_cv_knn,acc_cv_log,acc_cv_rf,acc_cv_gaussian,acc_cv_sgd,acc_cv_linear_svc,acc_cv_dt,acc_cv_gbt]})
#       8
#       9 models.sort_values(by='Score', ascending=False)
#
# NameError: name 'acc_cv_knn' is not defined

# %%
# Calculating PCA for dataset,and graphing the Variance for each feature
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
fit = pca.fit(X)

print( fit.explained_variance_ratio_ )

X_PCA=fit.components_


X_PCA.shape
# Out:
# [0.44652807 0.19615869 0.14481372]
# (3, 19)

# %%
plt.subplot(1, 2, 1)
plt.xlabel('PCA Feature')
plt.ylabel('Variance')
plt.title('PCA for Discretised Dataset')
plt.bar(range(0, fit.explained_variance_ratio_.size), fit.explained_variance_ratio_);

# %%
# Out:
#   File "<ipython-input-344-fecc1941cd40>", line 4
#     model = algo.fit(X_train, y_train)
#     ^
# IndentationError: unexpected indent

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = model1.predict_proba(X_test)

preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)
# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic -Model 1-LogisticRegression')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# (4298,)

# %%
models = pd.DataFrame({
    'Model': ['KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree', 'Gradient Boosting Trees'],
    'Score': ["Accuracy"]})
        
models.sort_values(by='Score', ascending=False)
